# %% [markdown]
# # Example: XRD spectra

# %% [markdown]
# ### Importing necessary packages

# %%
from datetime import datetime

# %%
from sdRDM import DataModel

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import pickle

# %% [markdown]
# ### Loading data model from GitHub

# %%
url_example_showcase = "https://github.com/FAIRChemistry/example_showcase.git"

# %%
model = DataModel.from_git(url=url_example_showcase)

# %% [markdown]
# ### Parsing XRD data

# %%
with open('XRD_data_set.txt', 'r') as f:
    content=f.readlines()
    num_lines=len(content)
    x,y=[],[]
    for i in range(52, num_lines):
        x.append(float(content[i].split()[0]))
        y.append(float(content[i].split()[1]))
#x=np.array(x)
#y=np.array(y)
#print(x)#
#print(y)
#print(len(x))
#print(len(y))
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### Dumping data with pickle

# %%
pickle.dump(content, ')
